# %% [markdown]
# # Python for Kids · Phase III — Your First Chart
#
# Companion notebook for the blog lesson. Read the lesson, then run each cell with Shift+Enter.

# %% [markdown]
# Load the data and the chart tool first. In Colab, charts appear right under the cell.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
penguins = sns.load_dataset("penguins").dropna()

# %% [markdown]
# ## A bar chart of counts
#
# Remember `value_counts()`? Add `.plot(kind="bar")` and it becomes a chart — one bar per species.

# %%
penguins["species"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# **Try it:** Make a bar chart of how many penguins live on each `island`.

# %% [markdown]
# ## A bar chart of averages
#
# Pair `groupby` with `.plot(kind="bar")` to chart a value per group — like the average weight of each species.

# %%
penguins.groupby("species")["body_mass_g"].mean().plot(kind="bar")
plt.show()

# %% [markdown]
# **Try it:** Chart the average `flipper_length_mm` per species.

# %% [markdown]
# ## Fix the bug
#
# This just *prints* the counts — it's missing the `.plot(...)` part. To draw them, add `.plot(kind="bar")` and `plt.show()`.

# %%
penguins["species"].value_counts()

# %% [markdown]
# ## Your mission
#
# Make two charts: (1) a bar chart of the count of each `sex`, and (2) a bar chart of the average `body_mass_g` per `island`. Then `print` one thing each chart tells you.
