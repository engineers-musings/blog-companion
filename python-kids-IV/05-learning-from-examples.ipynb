# %% [markdown]
# # Python for Kids · Phase IV — Learning From Examples
#
# Companion notebook for the blog lesson. Read the lesson, then run each cell with Shift+Enter.
#
# (No new library yet — just thinking and a little Python.)

# %% [markdown]
# ## The old way: write the rules
#
# Sort fruit into **apples** and **oranges** using two clues (**features**): the fruit's **weight** and how **bumpy** its skin is (0 = smooth, 10 = very bumpy). You *could* write rules by hand.

# %%
def guess_fruit(weight, bumpiness):
    if bumpiness > 5:
        return "orange"
    else:
        return "apple"

print(guess_fruit(150, 8))   # orange?
print(guess_fruit(140, 2))   # apple?

# %% [markdown]
# ## The ML way: show examples instead
#
# Machine learning flips it. You don't write the rule — you collect **labeled examples** and let the computer find the pattern. An example is some **features** plus the correct **label**.

# %%
# each row: [weight, bumpiness] -> label
examples = [
    [140, 2, "apple"],
    [145, 1, "apple"],
    [150, 3, "apple"],
    [160, 8, "orange"],
    [155, 7, "orange"],
    [165, 9, "orange"],
]

# %% [markdown]
# ### Try it 🎯
#
# Look at the `examples` list. Just by eye, what's the rough pattern? (Lower bumpiness → apple; higher bumpiness → orange. The computer will find a sharper version of exactly this.)
#
# The two words to remember: **Features** are the clues you measure (weight, bumpiness); the **Label** is the answer you want to predict (apple/orange).
