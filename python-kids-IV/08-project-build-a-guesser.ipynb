# %% [markdown]
# # Python for Kids · Phase IV — Project: Build a Guesser
#
# Companion notebook for the blog lesson. Read the lesson, then run each cell with Shift+Enter.

# %% [markdown]
# ## The five-step recipe
#
# Every supervised machine-learning project follows the same shape: data → features & label → split → fit → score.

# %%
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# 1. Get the data
penguins = sns.load_dataset("penguins").dropna()

# 2. Pick features (X) and the label (y)
X = penguins[["bill_length_mm", "flipper_length_mm", "body_mass_g"]]
y = penguins["species"]

# 3. Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 4. Train the model
model = KNeighborsClassifier()
model.fit(X_train, y_train)

# 5. Check how well it learned
print("Accuracy:", model.score(X_test, y_test))

# %% [markdown]
# ## Use your guesser
#
# Once trained, predict new penguins (a list-of-lists, even for one).

# %%
new_penguins = [
    [39, 190, 3700],
    [48, 215, 5000],
    [46, 200, 4200],
]
print(model.predict(new_penguins))

# %% [markdown]
# ## Make it your own 🚀
#
# Build a guesser *you* choose — a different label, different features, or a different dataset. Follow the same five steps, print the accuracy, and predict a few of your own examples.

# %%
# your guesser — pick a dataset, features, and label, then run the 5 steps
