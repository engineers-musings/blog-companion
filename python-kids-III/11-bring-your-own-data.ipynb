# %% [markdown]
# # Python for Kids · Phase III — Bring Your Own Data
#
# Companion notebook for the blog lesson. Read the lesson, then run each cell with Shift+Enter.

# %% [markdown]
# Load pandas and the chart tool first.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## More built-in datasets
#
# Seaborn comes with several practice datasets. See the list:

# %%
print(sns.get_dataset_names())

# %% [markdown]
# Let's try **tips** — data from a restaurant about bills and tips. Brand-new data, same moves.

# %%
tips = sns.load_dataset("tips")
tips.head()

# %% [markdown]
# ## The same skills, instantly
#
# Watch your penguin skills work on tips with no changes.

# %%
print("Rows and columns:", tips.shape)
print(tips["day"].value_counts())
print(tips.groupby("day")["tip"].mean())

# %%
tips.plot(kind="scatter", x="total_bill", y="tip", figsize=(8, 5))
plt.title("Bigger bills, bigger tips?")
plt.xlabel("Total bill")
plt.ylabel("Tip")
plt.show()

# %% [markdown]
# **Try it:**
# 1. Load the `titanic` dataset and run `.head()` and `.shape`.
# 2. On `tips`, find the average `total_bill` for each `time` (Lunch vs Dinner) with `groupby`.

# %% [markdown]
# ## Loading a CSV from the web
#
# Real data often lives in **CSV** files online. With an adult's help finding a link, load any of them with `read_csv`. Ask a grown-up to help you find a kid-safe CSV about a topic you love, then swap the URL below for your own.

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
mydata = pd.read_csv(url)
mydata.head()

# %% [markdown]
# ## Fix the bug
#
# This errors because `tips` has no `body_mass_g` — that was a penguin column. Check this dataset's columns with `tips.columns` and use one that exists, like `tips["total_bill"]`.

# %%
tips = sns.load_dataset("tips")
print(tips["body_mass_g"].mean())

# %% [markdown]
# ## Your mission
#
# Pick a **new** dataset (`tips`, `titanic`, or `mpg`) and fully explore it: print its `shape` and `columns`, run a `value_counts` on a category, compute a `groupby` average, and make one labeled chart.
