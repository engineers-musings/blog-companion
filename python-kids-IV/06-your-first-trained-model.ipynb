# %% [markdown]
# # Python for Kids · Phase IV — Train Your First Model
#
# Companion notebook for the blog lesson. Read the lesson, then run each cell with Shift+Enter.
#
# (scikit-learn is already installed in Colab — no `pip` needed.)

# %% [markdown]
# ## Set up the examples
#
# For penguins, the **features** are measurements and the **label** is the species. By tradition, the features are called `X` (a table of clues) and the label is called `y` (the answers).

# %%
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier

penguins = sns.load_dataset("penguins").dropna()

X = penguins[["bill_length_mm", "flipper_length_mm", "body_mass_g"]]   # features
y = penguins["species"]                                                # label

# %% [markdown]
# ## Train it: .fit()
#
# This is the moment of learning. Create a model and call `.fit(X, y)` — "learn the pattern from these examples."

# %%
model = KNeighborsClassifier()
model.fit(X, y)

# %% [markdown]
# ## Use it: .predict()
#
# Now give it a new penguin's measurements and ask what species it is — a bill length of 45mm, a flipper of 210mm, and a mass of 4500g.

# %%
guess = model.predict([[45, 210, 4500]])
print("I think this penguin is a:", guess[0])

# %% [markdown]
# ### Try it 🎯
#
# 1. Change the three numbers and predict again. Tiny penguin? Big one?
# 2. Look at a real row (`penguins.head()`), copy its three measurements into `predict`, and check if the model gets that species right.

# %% [markdown]
# 💡 The lesson shows a common mistake here — this is the working version.

# %%
model.predict([[45, 210, 4500]])
