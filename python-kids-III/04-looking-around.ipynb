# %% [markdown]
# # Python for Kids · Phase III — Looking Around the Data
#
# Companion notebook for the blog lesson. Read the lesson, then run each cell with Shift+Enter.

# %% [markdown]
# ## Load the data first
#
# Start every lesson by loading the penguins.

# %%
import pandas as pd
import seaborn as sns
penguins = sns.load_dataset("penguins").dropna()

# %% [markdown]
# ## Grabbing one column
#
# Use square brackets with a column name to pull out that column. A single column is called a **Series** — basically a labeled list.

# %%
penguins["species"].head()

# %% [markdown]
# ## Grabbing several columns
#
# Want more than one column? Pass a **list** of names (note the double brackets).

# %%
penguins[["species", "body_mass_g"]].head()

# %% [markdown]
# ## What values appear?
#
# `.unique()` lists the different values in a column — great for categories like species or island.

# %%
print(penguins["species"].unique())
print(penguins["island"].unique())

# %% [markdown]
# ## A column is just a list of numbers
#
# Number columns can do math, all at once — no loop needed.

# %%
print("Heaviest penguin:", penguins["body_mass_g"].max())
print("Lightest penguin:", penguins["body_mass_g"].min())
print("Average weight:", penguins["body_mass_g"].mean())
